# %%
import pandas as pd
import joblib

# %% [markdown]
# Predicting next year's points using this year's stats

# %%
# Load the trained model
model = joblib.load('random_forest_model.pkl')

# %%
df = pd.read_csv(r'Data/seasonstats_imputed.csv')

# %%
# Bring in data from the 2023/2024 season
current_season_df = df[df['Season'] == '2023/2024']

# %%
current_season_df.shape
# Out:
# (20, 23)

# %%
# Ensure the DataFrame has the same structure as the training data
X_current_season = current_season_df.drop(columns=['Unnamed: 0', 'Season', 'Squad', 'Pts'])

# %%
X_current_season.shape
# Out:
# (20, 19)

# %%
# Make predictions for the next season's points
predicted_points = model.predict(X_current_season)

# %%
current_season_df
# Out:
#     Unnamed: 0     Season            Squad  Att_prev  CK_prev  Cmp%_prev  \
# 0            0  2023/2024  Manchester City   21969.0    223.0      83.20
# 1            1  2023/2024          Arsenal   17396.0    162.0      79.20
# 2            2  2023/2024        Liverpool   22888.0    233.0      83.90
# 3            3  2023/2024      Aston Villa   17308.0    186.0      77.40
# 4            4  2023/2024        Tottenham   15783.0    174.0      74.70
# 5            5  2023/2024          Chelsea   24361.0    235.0      82.30
# 6            6  2023/2024    Newcastle Utd   15551.0    163.0      72.80
# 7            7  2023/2024   Manchester Utd   15381.0    144.0      76.20
# 8            8  2023/2024         West Ham   20525.0    196.0      80.90
# 9            9  2023/2024   Crystal Palace   18871.0    135.0      78.90
# 10          10  2023/2024         Brighton   22836.0    209.0      83.80
# 11          11  2023/2024      Bournemouth   17837.0    270.0      78.10
# 12          12  2023/2024           Fulham   16924.0    199.0      73.50
# 13          13  2023/2024           Wolves   26642.0    238.0      87.30
# 14          14  2023/2024          Everton   16391.0    157.0      75.20
# 15          15  2023/2024        Brentford   18014.0    182.0      77.60
# 16          16  2023/2024  Nott'ham Forest   13606.0    128.0      70.10
# 17          17  2023/2024       Luton Town   17345.8    173.6      76.16
# 18          18  2023/2024          Burnley   17921.8    171.4      77.08
# 19          19  2023/2024    Sheffield Utd   17921.8    171.4      77.08
#
#     Cmp_prev  CrdR_prev  CrdY_prev  D_prev  ...  GF_prev  L_prev  OG_prev  \
# 0    18281.0        0.0       51.0     5.0  ...     94.0     5.0      1.0
# 1    13782.0        1.0       80.0     6.0  ...     88.0     6.0      4.0
# 2    19210.0        0.0       58.0    10.0  ...     75.0     9.0      6.0
# 3    13395.0        3.0       82.0     7.0  ...     51.0    13.0      3.0
# 4    11790.0        2.0       81.0     6.0  ...     70.0    14.0      0.0
# 5    20043.0        1.0       57.0    11.0  ...     38.0    16.0      2.0
# 6    11317.0        1.0       57.0    14.0  ...     68.0     5.0      3.0
# 7    11715.0        0.0       68.0     6.0  ...     58.0     9.0      3.0
# 8    16603.0        2.0       78.0     7.0  ...     42.0    20.0      1.0
# 9    14887.0        2.0       63.0    12.0  ...     40.0    15.0      5.0
# 10   19147.0        3.0       81.0     8.0  ...     72.0    12.0      3.0
# 11   13925.0        1.0       61.0     6.0  ...     37.0    21.0      2.0
# 12   12437.0        3.0       89.0     7.0  ...     55.0    16.0      1.0
# 13   23263.0        1.0       44.0     8.0  ...     31.0    19.0      1.0
# 14   12319.0        0.0       73.0    12.0  ...     34.0    18.0      5.0
# 15   13974.0        1.0       80.0    14.0  ...     58.0     9.0      2.0
# 16    9543.0        0.0       84.0    11.0  ...     38.0    18.0      0.0
# 17   13375.4        2.6       56.8     3.2  ...     53.2    11.0      2.0
# 18   13946.8        2.8       54.8     8.2  ...     54.8    16.6      1.4
# 19   13946.8        2.2       49.6     7.6  ...     39.8    14.8      1.4
#
#     PK_prev  PKcon_prev   Pts  Pts_prev  Sh_prev  SoT_prev  W_prev
# 0       3.0         5.0  91.0      89.0    589.0     194.0    28.0
# 1       3.0         6.0  89.0      84.0    427.0     145.0    26.0
# 2       6.0         8.0  82.0      67.0    607.0     219.0    19.0
# 3       1.0         4.0  68.0      61.0    423.0     133.0    18.0
# 4       3.0         6.0  66.0      60.0    426.0     143.0    18.0
# 5       2.0         4.0  63.0      44.0    601.0     203.0    11.0
# 6       7.0         2.0  60.0      71.0    400.0     147.0    19.0
# 7       0.0         7.0  60.0      75.0    358.0     126.0    23.0
# 8       3.0         3.0  52.0      40.0    590.0     206.0    11.0
# 9       3.0         5.0  49.0      45.0    412.0     142.0    11.0
# 10      3.0         1.0  48.0      62.0    481.0     151.0    18.0
# 11      6.0         5.0  48.0      39.0    565.0     184.0    11.0
# 12      1.0         6.0  47.0      52.0    459.0     141.0    15.0
# 13      9.0         3.0  46.0      41.0    590.0     205.0    11.0
# 14      2.0         3.0  42.0      36.0    413.0     132.0     8.0
# 15      5.0         8.0  39.0      59.0    420.0     137.0    15.0
# 16      3.0         9.0  32.0      38.0    362.0     111.0     9.0
# 17      3.8         7.0  26.0      26.8    436.2     184.6    11.8
# 18      4.2         7.8  24.0      42.2    417.8     192.0    13.2
# 19      2.8         7.8  16.0      34.0    417.8     151.0    10.0
#
# [20 rows x 23 columns]

# %%
current_season_df['Predicted Points 2024/2025'] = predicted_points
# Out:
# C:\Users\YahyaLadiwala\AppData\Local\Temp\ipykernel_19948\1604986241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_season_df['Predicted Points 2024/2025'] = predicted_points

# %%
current_season_df.sort_values(by='Predicted Points 2024/2025', ascending=False)
# Out:
#     Unnamed: 0     Season            Squad  Att_prev  CK_prev  Cmp%_prev  \
# 0            0  2023/2024  Manchester City   21969.0    223.0      83.20
# 1            1  2023/2024          Arsenal   17396.0    162.0      79.20
# 2            2  2023/2024        Liverpool   22888.0    233.0      83.90
# 3            3  2023/2024      Aston Villa   17308.0    186.0      77.40
# 7            7  2023/2024   Manchester Utd   15381.0    144.0      76.20
# 4            4  2023/2024        Tottenham   15783.0    174.0      74.70
# 6            6  2023/2024    Newcastle Utd   15551.0    163.0      72.80
# 5            5  2023/2024          Chelsea   24361.0    235.0      82.30
# 10          10  2023/2024         Brighton   22836.0    209.0      83.80
# 8            8  2023/2024         West Ham   20525.0    196.0      80.90
# 12          12  2023/2024           Fulham   16924.0    199.0      73.50
# 13          13  2023/2024           Wolves   26642.0    238.0      87.30
# 9            9  2023/2024   Crystal Palace   18871.0    135.0      78.90
# 11          11  2023/2024      Bournemouth   17837.0    270.0      78.10
# 14          14  2023/2024          Everton   16391.0    157.0      75.20
# 15          15  2023/2024        Brentford   18014.0    182.0      77.60
# 16          16  2023/2024  Nott'ham Forest   13606.0    128.0      70.10
# 17          17  2023/2024       Luton Town   17345.8    173.6      76.16
# 18          18  2023/2024          Burnley   17921.8    171.4      77.08
# 19          19  2023/2024    Sheffield Utd   17921.8    171.4      77.08
#
#     Cmp_prev  CrdR_prev  CrdY_prev  D_prev  ...  L_prev  OG_prev  PK_prev  \
# 0    18281.0        0.0       51.0     5.0  ...     5.0      1.0      3.0
# 1    13782.0        1.0       80.0     6.0  ...     6.0      4.0      3.0
# 2    19210.0        0.0       58.0    10.0  ...     9.0      6.0      6.0
# 3    13395.0        3.0       82.0     7.0  ...    13.0      3.0      1.0
# 7    11715.0        0.0       68.0     6.0  ...     9.0      3.0      0.0
# 4    11790.0        2.0       81.0     6.0  ...    14.0      0.0      3.0
# 6    11317.0        1.0       57.0    14.0  ...     5.0      3.0      7.0
# 5    20043.0        1.0       57.0    11.0  ...    16.0      2.0      2.0
# 10   19147.0        3.0       81.0     8.0  ...    12.0      3.0      3.0
# 8    16603.0        2.0       78.0     7.0  ...    20.0      1.0      3.0
# 12   12437.0        3.0       89.0     7.0  ...    16.0      1.0      1.0
# 13   23263.0        1.0       44.0     8.0  ...    19.0      1.0      9.0
# 9    14887.0        2.0       63.0    12.0  ...    15.0      5.0      3.0
# 11   13925.0        1.0       61.0     6.0  ...    21.0      2.0      6.0
# 14   12319.0        0.0       73.0    12.0  ...    18.0      5.0      2.0
# 15   13974.0        1.0       80.0    14.0  ...     9.0      2.0      5.0
# 16    9543.0        0.0       84.0    11.0  ...    18.0      0.0      3.0
# 17   13375.4        2.6       56.8     3.2  ...    11.0      2.0      3.8
# 18   13946.8        2.8       54.8     8.2  ...    16.6      1.4      4.2
# 19   13946.8        2.2       49.6     7.6  ...    14.8      1.4      2.8
#
#     PKcon_prev   Pts  Pts_prev  Sh_prev  SoT_prev  W_prev  \
# 0          5.0  91.0      89.0    589.0     194.0    28.0
# 1          6.0  89.0      84.0    427.0     145.0    26.0
# 2          8.0  82.0      67.0    607.0     219.0    19.0
# 3          4.0  68.0      61.0    423.0     133.0    18.0
# 7          7.0  60.0      75.0    358.0     126.0    23.0
# 4          6.0  66.0      60.0    426.0     143.0    18.0
# 6          2.0  60.0      71.0    400.0     147.0    19.0
# 5          4.0  63.0      44.0    601.0     203.0    11.0
# 10         1.0  48.0      62.0    481.0     151.0    18.0
# 8          3.0  52.0      40.0    590.0     206.0    11.0
# 12         6.0  47.0      52.0    459.0     141.0    15.0
# 13         3.0  46.0      41.0    590.0     205.0    11.0
# 9          5.0  49.0      45.0    412.0     142.0    11.0
# 11         5.0  48.0      39.0    565.0     184.0    11.0
# 14         3.0  42.0      36.0    413.0     132.0     8.0
# 15         8.0  39.0      59.0    420.0     137.0    15.0
# 16         9.0  32.0      38.0    362.0     111.0     9.0
# 17         7.0  26.0      26.8    436.2     184.6    11.8
# 18         7.8  24.0      42.2    417.8     192.0    13.2
# 19         7.8  16.0      34.0    417.8     151.0    10.0
#
#     Predicted Points 2024/2025
# 0                        86.51
# 1                        84.13
# 2                        76.53
# 3                        65.88
# 7                        65.26
# 4                        61.94
# 6                        59.45
# 5                        55.93
# 10                       50.52
# 8                        48.86
# 12                       48.76
# 13                       47.14
# 9                        45.98
# 11                       44.48
# 14                       41.54
# 15                       41.12
# 16                       29.60
# 17                       26.00
# 18                       24.06
# 19                       16.39
#
# [20 rows x 24 columns]

# %% [markdown]
# Results

# %% [markdown]
# - Top Ten Teams:
#     - #1 Manchester City (86.51 points)
#     - #2 Arsenal (84.13 points)
#     - #3 Liverpool (76.53 points)
#     - #4 Aston Villa (65.88 points)
#     - #5 Manchester United (65.26 points)
#     - #6 Tottenham (61.94 points)
#     - #7 Newcastle United (59.45 points)
#     - #8 Chelsea (55.93 points)
#     - #9 Brighton (50.52 points)
#     - #10 Westham (48.86 points)
#
# - Changes from last year's rankings
#     - Manchester United: 8 -> 5 (+3)
#     - Tottenham: 5 -> 6 (-1)
#     - Chelsea: 6 -> 8 (-2)
#     - Brighton: 11 -> 9 (+2)
#     - Westham 0 -> 10 (-1)

# %% [markdown]
# Second Model

# %%
# Load the trained model
model = joblib.load('random_forest_model_2.0.pkl')

# %%
df = pd.read_csv(r'Data/seasonstats_key_features.csv')

# %%
# Bring in data from the 2023/2024 season
current_season_df = df[df['Season'] == '2023/2024']

# %%
current_season_df.shape
# Out:
# (20, 14)

# %%
# Ensure the DataFrame has the same structure as the training data
X_current_season = current_season_df.drop(columns=['Unnamed: 0', 'Season', 'Squad', 'Pts'])

# %%
X_current_season.shape
# Out:
# (20, 10)

# %%
# Make predictions for the next season's points
predicted_points = model.predict(X_current_season)

# %%
current_season_df['Predicted Points 2024/2025'] = predicted_points
# Out:
# C:\Users\YahyaLadiwala\AppData\Local\Temp\ipykernel_19948\1604986241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_season_df['Predicted Points 2024/2025'] = predicted_points

# %%
current_season_df.sort_values(by='Predicted Points 2024/2025', ascending=False)
# Out:
#     Unnamed: 0     Season            Squad  CrdR_prev  CrdY_prev  D_prev  \
# 0            0  2023/2024  Manchester City        0.0       51.0     5.0
# 1            1  2023/2024          Arsenal        1.0       80.0     6.0
# 2            2  2023/2024        Liverpool        0.0       58.0    10.0
# 3            3  2023/2024      Aston Villa        3.0       82.0     7.0
# 7            7  2023/2024   Manchester Utd        0.0       68.0     6.0
# 4            4  2023/2024        Tottenham        2.0       81.0     6.0
# 6            6  2023/2024    Newcastle Utd        1.0       57.0    14.0
# 5            5  2023/2024          Chelsea        1.0       57.0    11.0
# 10          10  2023/2024         Brighton        3.0       81.0     8.0
# 8            8  2023/2024         West Ham        2.0       78.0     7.0
# 12          12  2023/2024           Fulham        3.0       89.0     7.0
# 9            9  2023/2024   Crystal Palace        2.0       63.0    12.0
# 13          13  2023/2024           Wolves        1.0       44.0     8.0
# 11          11  2023/2024      Bournemouth        1.0       61.0     6.0
# 15          15  2023/2024        Brentford        1.0       80.0    14.0
# 14          14  2023/2024          Everton        0.0       73.0    12.0
# 16          16  2023/2024  Nott'ham Forest        0.0       84.0    11.0
# 17          17  2023/2024       Luton Town        2.6       56.8     3.2
# 18          18  2023/2024          Burnley        2.8       54.8     8.2
# 19          19  2023/2024    Sheffield Utd        2.2       49.6     7.6
#
#     Fls_prev  GA_prev  L_prev  PK_prev  PKcon_prev   Pts  Pts_prev  Sh_prev  \
# 0      373.0     33.0     5.0      3.0         5.0  91.0      89.0    589.0
# 1      417.0     43.0     6.0      3.0         6.0  89.0      84.0    427.0
# 2      427.0     47.0     9.0      6.0         8.0  82.0      67.0    607.0
# 3      446.0     46.0    13.0      1.0         4.0  68.0      61.0    423.0
# 7      391.0     43.0     9.0      0.0         7.0  60.0      75.0    358.0
# 4      396.0     63.0    14.0      3.0         6.0  66.0      60.0    426.0
# 6      354.0     33.0     5.0      7.0         2.0  60.0      71.0    400.0
# 5      405.0     47.0    16.0      2.0         4.0  63.0      44.0    601.0
# 10     397.0     53.0    12.0      3.0         1.0  48.0      62.0    481.0
# 8      424.0     55.0    20.0      3.0         3.0  52.0      40.0    590.0
# 12     467.0     53.0    16.0      1.0         6.0  47.0      52.0    459.0
# 9      410.0     49.0    15.0      3.0         5.0  49.0      45.0    412.0
# 13     347.0     58.0    19.0      9.0         3.0  46.0      41.0    590.0
# 11     406.0     71.0    21.0      6.0         5.0  48.0      39.0    565.0
# 15     411.0     46.0     9.0      5.0         8.0  39.0      59.0    420.0
# 14     430.0     57.0    18.0      2.0         3.0  42.0      36.0    413.0
# 16     445.0     68.0    18.0      3.0         9.0  32.0      38.0    362.0
# 17     460.0     49.4    11.0      3.8         7.0  26.0      26.8    436.2
# 18     406.2     61.2    16.6      4.2         7.8  24.0      42.2    417.8
# 19     423.6     57.8    14.8      2.8         7.8  16.0      34.0    417.8
#
#     Predicted Points 2024/2025
# 0                        86.42
# 1                        83.75
# 2                        76.48
# 3                        64.62
# 7                        64.38
# 4                        61.02
# 6                        60.57
# 5                        56.53
# 10                       54.33
# 8                        49.84
# 12                       49.73
# 9                        48.30
# 13                       47.52
# 11                       46.00
# 15                       41.71
# 14                       40.59
# 16                       31.33
# 17                       25.99
# 18                       24.26
# 19                       16.29
